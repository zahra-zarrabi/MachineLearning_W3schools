# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy import stats
from sklearn import *   #from sklearn.metrics import r2_score  and  from sklearn import linear_model   
from sklearn.preprocessing import StandardScaler
import pandas

# %%
# Mean
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
average=np.mean(speed)
print('average :',average)

# Median
median=np.median(speed)
print('Median :',median)

# Mode
mode=stats.mode(speed)
print('Mode :',mode)
# Out:
# average : 89.76923076923077
# Median : 87.0
# Mode : ModeResult(mode=array([86]), count=array([3]))

# %%
# Standard Deviation
speed = [86,87,88,86,87,85,86]
standard=np.std(speed)
print('Standard Deviation :',standard)

# Variance
speed = [32,111,138,28,59,77,97]
variance=np.var(speed)
print('Variance:',variance)
# Out:
# Standard Deviation : 0.9035079029052513
# Variance: 1432.2448979591834

# %%
# Percentiles
ages = [5,31,43,48,50,41,7,11,15,39,80,82,32,2,8,6,25,36,27,61,31]
percentiles=np.percentile(ages,80)
print('Percentiles :',percentiles)
# Out:
# Percentiles : 48.0

# %%
# Data Distribution
x=np.random.uniform(0.0,5.0,10)
print(x)
plt.hist(x,6)
plt.show()
# Out:
# [3.23344225 4.37010106 2.66168617 4.28857171 0.89830259 3.46075057
#  2.21678491 0.37355596 3.48486745 0.17056768]

# %%
# Normal Data Distribution
x = numpy.random.normal(6.0, 1.0, 10000)
print(x)
plt.hist(x,100)
plt.show()
# Out:
# [6.44902497 6.68512571 4.4000528  ... 5.79905841 6.85342639 6.82028639]

# %%
# Scatter Plot
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.show()

# %%
# Random Data Distributions
x = numpy.random.normal(5.0, 1.0, 1000)
y = numpy.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()

# %%
# Linear Regression
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
# Predict Future Values
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)

print(speed)
# Out:
# 85.59308314937454

# %%
#  bad Predict 
x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
print(r)
# Out:
# 0.01331814154297491

# %%
#Polynomial Regression

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y,3))

myline = numpy.linspace(1, 20, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

print(r2_score(y, mymodel(x)))

#
speed = mymodel(17)
print(speed)
# Out:
# 0.9432150416451027
# 88.87331269697978

# %%
# Multiple Regression
df = pandas.read_csv("cars.csv")

X = df[['Weight', 'Volume']]
y = df['CO2']
regr = linear_model.LinearRegression()
regr.fit(X, y)
predictedCO2 = regr.predict([[2300, 1300]])
print(predictedCO2)

print(regr.coef_)
# Out:
# [107.2087328]
# [0.00755095 0.00780526]

# %%
#Scale
scale = StandardScaler()

df = pandas.read_csv("cars.csv")
X = df[['Weight', 'Volume']]
scaledX = scale.fit_transform(X)
print(scaledX)

y = df['CO2']
regr = linear_model.LinearRegression()
regr.fit(scaledX, y)
scaled = scale.transform([[2300, 1.3]])
predictedCO2 = regr.predict([scaled[0]])
print('predictedCO2',predictedCO2)
# Out:
# [[-2.10389253 -1.59336644]
#  [-0.55407235 -1.07190106]
#  [-1.52166278 -1.59336644]
#  [-1.78973979 -1.85409913]
#  [-0.63784641 -0.28970299]
#  [-1.52166278 -1.59336644]
#  [-0.76769621 -0.55043568]
#  [ 0.3046118  -0.28970299]
#  [-0.7551301  -0.28970299]
#  [-0.59595938 -0.0289703 ]
#  [-1.30803892 -1.33263375]
#  [-1.26615189 -0.81116837]
#  [-0.7551301  -1.59336644]
#  [-0.16871166 -0.0289703 ]
#  [ 0.14125238 -0.0289703 ]
#  [ 0.15800719 -0.0289703 ]
#  [ 0.3046118  -0.0289703 ]
#  [-0.05142797  1.53542584]
#  [-0.72580918 -0.0289703 ]
#  [ 0.14962979  1.01396046]
#  [ 1.2219378  -0.0289703 ]
#  [ 0.5685001   1.01396046]
#  [ 0.3046118   1.27469315]
#  [ 0.51404696 -0.0289703 ]
#  [ 0.51404696  1.01396046]
#  [ 0.72348212 -0.28970299]
#  [ 0.8281997   1.01396046]
#  [ 1.81254495  1.01396046]
#  [ 0.96642691 -0.0289703 ]
#  [ 1.72877089  1.01396046]
#  [ 1.30990057  1.27469315]
#  [ 1.90050772  1.01396046]
#  [-0.23991961 -0.0289703 ]
#  [ 0.40932938 -0.0289703 ]
#  [ 0.47215993 -0.0289703 ]
#  [ 0.4302729   2.31762392]]
# predictedCO2 [97.07204485]
